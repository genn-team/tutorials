# %% [markdown]
# # Install PyGeNN
# Use apt-get to install FFI (required to build PyGeNN from source)

# %%
# !apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libffi-dev is already the newest version (3.4.2-4).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.

# %% [markdown]
# Checkout latest GeNN release from GitHub (ignore warnings about detached heads)

# %%
# %cd /content
# !rm -rf /content/genn /content/riscv_ise
# !git clone https://github.com/genn-team/genn.git --branch fixed_point
# !git clone https://github.com/neworderofjamie/riscv_ise.git --branch compiler
# Out:
# /content
# Cloning into 'genn'...
# remote: Enumerating objects: 133317, done.
# remote: Counting objects: 100% (3064/3064), done.
# remote: Compressing objects: 100% (755/755), done.
# remote: Total 133317 (delta 2461), reused 2309 (delta 2309), pack-reused 130253 (from 5)
# Receiving objects: 100% (133317/133317), 253.51 MiB | 24.50 MiB/s, done.
# Resolving deltas: 100% (94433/94433), done.
# Cloning into 'riscv_ise'...
# remote: Enumerating objects: 4755, done.
# remote: Counting objects: 100% (1616/1616), done.
# remote: Compressing objects: 100% (512/512), done.
# remote: Total 4755 (delta 1222), reused 1438 (delta 1092), pack-reused 3139 (from 1)
# Receiving objects: 100% (4755/4755), 35.85 MiB | 15.52 MiB/s, done.
# Resolving deltas: 100% (3386/3386), done.

# %% [markdown]
# Go into our newly created GeNN directory, build the dynamic version of the GeNN library into PyFeNN

# %%
# %env GENN_PATH=/content/genn
# Out:
# env: GENN_PATH=/content/genn

# %%
# !make -C /content/genn/src/genn/genn DYNAMIC=1 LIBRARY_DIRECTORY=/content/riscv_ise/pyfenn -j 2
# Out:
# make: Entering directory '/content/genn/src/genn/genn'
# mkdir -p /content/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/genn/include/genn/genn -I/content/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"6ae098d37c5a4bc28475036af0341a1b22304d4d\" -c -o /content/genn/obj_dynamic/genn/genn/binomial.o binomial.cc
# mkdir -p /content/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/genn/include/genn/genn -I/content/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"6ae098d37c5a4bc28475036af0341a1b22304d4d\" -c -o /content/genn/obj_dynamic/genn/genn/currentSource.o currentSource.cc
# mkdir -p /content/genn/obj_dynamic/genn/genn
# ...

# %%
# %cd /content/riscv_ise/
# !pip wheel .
# Out:
# /content/riscv_ise
# Processing /content/riscv_ise
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.0 MB/s eta 0:00:00
# Saved ./numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./setuptools-80.0.0-py3-none-any.whl
# ...
#   Created wheel for pyfenn: filename=pyfenn-0.0.1-cp311-cp311-linux_x86_64.whl size=6370993 sha256=d19e8c731f8cd9b4e86653cc449d50a2d54159bee8bd6d802cf0334ab68afa95
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vpq9f6vj/wheels/5c/37/3b/0f59c6da75873ee59ffb761e29c25b16947692c5ddb5ce1ec7
# Successfully built pyfenn

# %% [markdown]
# # Save wheel to Google Drive
# First mount Google drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# and then copy wheel file into folder with tutorials

# %%
from platform import python_implementation, python_version_tuple
from shutil import copy
#from wheel.bdist_wheel import get_abi_tag, get_platform

assert python_implementation() == "CPython"
version_tuple = python_version_tuple()
#wheel_name = f"pyfenn-0.0.1-cp{version_tuple[0]}{version_tuple[1]}-{get_abi_tag()}-{get_platform(None)}.whl"
wheel_name = f"pyfenn-0.0.1-cp{version_tuple[0]}{version_tuple[1]}-cp311-linux_x86_64.whl"
copy(f"/content/riscv_ise/{wheel_name}", f"/content/drive/MyDrive/genn_tutorials/{wheel_name}")
# Out:
# '/content/drive/MyDrive/genn_tutorials/pyfenn-0.0.1-cp311-cp311-linux_x86_64.whl'
