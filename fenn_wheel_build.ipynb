# %% [markdown]
# # Install PyGeNN
# Use apt-get to install FFI (required to build PyGeNN from source)

# %%
# !apt-get install libffi-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libffi-dev is already the newest version (3.4.2-4).
# libffi-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %% [markdown]
# Checkout latest GeNN release from GitHub (ignore warnings about detached heads)

# %%
# %cd /content
# !rm -rf /content/riscv_ise
# !git clone https://github.com/neworderofjamie/riscv_ise.git --recurse-submodules
# Out:
# /content
# Cloning into 'riscv_ise'...
# remote: Enumerating objects: 7371, done.
# remote: Counting objects: 100% (1031/1031), done.
# remote: Compressing objects: 100% (220/220), done.
# remote: Total 7371 (delta 900), reused 896 (delta 811), pack-reused 6340 (from 3)
# Receiving objects: 100% (7371/7371), 44.11 MiB | 16.87 MiB/s, done.
# Resolving deltas: 100% (5292/5292), done.
# Submodule 'genn' (https://github.com/genn-team/genn.git) registered for path 'genn'
# Submodule 'udmabuf' (https://github.com/ikwzm/udmabuf.git) registered for path 'udmabuf'
# Cloning into '/content/riscv_ise/genn'...
# remote: Enumerating objects: 135106, done.
# remote: Counting objects: 100% (4720/4720), done.
# remote: Compressing objects: 100% (1190/1190), done.
# remote: Total 135106 (delta 3708), reused 3704 (delta 3412), pack-reused 130386 (from 5)
# Receiving objects: 100% (135106/135106), 253.71 MiB | 17.03 MiB/s, done.
# Resolving deltas: 100% (95555/95555), done.
# Cloning into '/content/riscv_ise/udmabuf'...
# remote: Enumerating objects: 1423, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 1423 (delta 198), reused 175 (delta 175), pack-reused 1217 (from 3)
# Receiving objects: 100% (1423/1423), 562.41 KiB | 23.43 MiB/s, done.
# Resolving deltas: 100% (865/865), done.
# Submodule path 'genn': checked out '50bb2fce54ba168b40675feb6c53dc8a1b8f9b23'
# Submodule path 'udmabuf': checked out 'dfd4e97ccd7e67ddcebb29bd70b1ef1a894c70fd'

# %% [markdown]
# Go into our newly created GeNN directory, build the dynamic version of the GeNN library into PyFeNN

# %%
# %cd /content/riscv_ise/
# !pip install psutil pybind11 numpy
# !python setup.py bdist_wheel
# Out:
# /content/riscv_ise
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (5.9.5)
# Collecting pybind11
#   Downloading pybind11-3.0.1-py3-none-any.whl.metadata (10.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Downloading pybind11-3.0.1-py3-none-any.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.6/293.6 kB 16.0 MB/s eta 0:00:00
# Installing collected packages: pybind11
# Successfully installed pybind11-3.0.1
# make -C src/assembler
# make[1]: Entering directory '/content/riscv_ise/src/assembler'
# mkdir -p /content/riscv_ise/obj_dynamic/assembler/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/assembler//assembler.o assembler.cc
# mkdir -p /content/riscv_ise/obj_dynamic/assembler/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/assembler//assembler_utils.o assembler_utils.cc
# mkdir -p /content/riscv_ise/pyfenn
# g++ -shared -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -o /content/riscv_ise/pyfenn/libassembler_dynamic.so /content/riscv_ise/obj_dynamic/assembler//assembler.o /content/riscv_ise/obj_dynamic/assembler//assembler_utils.o
# make[1]: Leaving directory '/content/riscv_ise/src/assembler'
# make -C src/common
# make[1]: Entering directory '/content/riscv_ise/src/common'
# mkdir -p /content/riscv_ise/obj_dynamic/common/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/common//app_utils.o app_utils.cc
# mkdir -p /content/riscv_ise/obj_dynamic/common/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/common//device.o device.cc
# mkdir -p /content/riscv_ise/obj_dynamic/common/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/common//dma_buffer.o dma_buffer.cc
# mkdir -p /content/riscv_ise/obj_dynamic/common/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/common//dma_controller.o dma_controller.cc
# mkdir -p /content/riscv_ise/obj_dynamic/common/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/common//isa.o isa.cc
# mkdir -p /content/riscv_ise/pyfenn
# g++ -shared -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -o /content/riscv_ise/pyfenn/libcommon_dynamic.so /content/riscv_ise/obj_dynamic/common//app_utils.o /content/riscv_ise/obj_dynamic/common//device.o /content/riscv_ise/obj_dynamic/common//dma_buffer.o /content/riscv_ise/obj_dynamic/common//dma_controller.o /content/riscv_ise/obj_dynamic/common//isa.o
# make[1]: Leaving directory '/content/riscv_ise/src/common'
# make -C src/compiler
# make[1]: Entering directory '/content/riscv_ise/src/compiler'
# mkdir -p /content/riscv_ise/obj_dynamic/compiler/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/compiler//compiler.o compiler.cc
# compiler.cc: In member function ‘virtual void {anonymous}::Visitor::visit(const GeNN::Transpiler::Expression::ArraySubscript&)’:
# compiler.cc:124:58: warning: unused parameter ‘arraySubscript’ [-Wunused-parameter]
#   124 |     virtual void visit(const Expression::ArraySubscript &arraySubscript) final
#       |                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~
# compiler.cc: In member function ‘virtual void {anonymous}::Visitor::visit(const GeNN::Transpiler::Statement::For&)’:
# compiler.cc:629:46: warning: unused parameter ‘forStatement’ [-Wunused-parameter]
#   629 |     virtual void visit(const Statement::For &forStatement) final
#       |                        ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# compiler.cc: In member function ‘virtual void {anonymous}::Visitor::visit(const GeNN::Transpiler::Statement::ForEachSynapse&)’:
# compiler.cc:663:57: warning: unused parameter ‘forEachSynapseStatement’ [-Wunused-parameter]
#   663 |     virtual void visit(const Statement::ForEachSynapse &forEachSynapseStatement) final
#       |                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# compiler.cc: In member function ‘virtual void {anonymous}::Visitor::visit(const GeNN::Transpiler::Statement::Labelled&)’:
# compiler.cc:707:51: warning: unused parameter ‘labelled’ [-Wunused-parameter]
#   707 |     virtual void visit(const Statement::Labelled &labelled) final
#       |                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~
# compiler.cc: In member function ‘virtual void {anonymous}::Visitor::visit(const GeNN::Transpiler::Statement::Switch&)’:
# compiler.cc:712:49: warning: unused parameter ‘switchStatement’ [-Wunused-parameter]
#   712 |     virtual void visit(const Statement::Switch &switchStatement) final
#       |                        ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~
# mkdir -p /content/riscv_ise/obj_dynamic/compiler/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/compiler//process.o process.cc
# process.cc: In constructor ‘EventPropagationProcess::EventPropagationProcess(ModelComponent::Private, std::shared_ptr<const EventContainer>, VariablePtr, VariablePtr, size_t, size_t, const string&)’:
# process.cc:119:46: warning: comparison of integer expressions of different signedness: ‘size_t’ {aka ‘long unsigned int’} and ‘int’ [-Wsign-compare]
#   119 |         if(m_Target->getNumBufferTimesteps() != (1 << (m_NumDelayBits - 1))) {
#       |            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# mkdir -p /content/riscv_ise/obj_dynamic/compiler/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/compiler//shape.o shape.cc
# mkdir -p /content/riscv_ise/pyfenn
# g++ -shared -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -o /content/riscv_ise/pyfenn/libcompiler_dynamic.so /content/riscv_ise/obj_dynamic/compiler//compiler.o /content/riscv_ise/obj_dynamic/compiler//process.o /content/riscv_ise/obj_dynamic/compiler//shape.o
# make[1]: Leaving directory '/content/riscv_ise/src/compiler'
# make -C src/disassembler
# make[1]: Entering directory '/content/riscv_ise/src/disassembler'
# mkdir -p /content/riscv_ise/obj_dynamic/disassembler/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/disassembler//disassembler.o disassembler.cc
# mkdir -p /content/riscv_ise/pyfenn
# g++ -shared -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -o /content/riscv_ise/pyfenn/libdisassembler_dynamic.so /content/riscv_ise/obj_dynamic/disassembler//disassembler.o
# make[1]: Leaving directory '/content/riscv_ise/src/disassembler'
# make -C genn/src/genn/genn
# make[1]: Entering directory '/content/riscv_ise/genn/src/genn/genn'
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/binomial.o binomial.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/currentSource.o currentSource.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/currentSourceModels.o currentSourceModels.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/customConnectivityUpdate.o customConnectivityUpdate.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/customConnectivityUpdateModels.o customConnectivityUpdateModels.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/customUpdate.o customUpdate.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/customUpdateModels.o customUpdateModels.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/gennUtils.o gennUtils.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/initSparseConnectivitySnippet.o initSparseConnectivitySnippet.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/initToeplitzConnectivitySnippet.o initToeplitzConnectivitySnippet.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/initVarSnippet.o initVarSnippet.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/logging.o logging.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/models.o models.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/modelSpec.o modelSpec.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/neuronGroup.o neuronGroup.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/neuronModels.o neuronModels.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/postsynapticModels.o postsynapticModels.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/snippet.o snippet.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/synapseGroup.o synapseGroup.cc
# mkdir -p /content/riscv_ise/genn/obj_dynamic/genn/genn
# g++ -std=c++17 -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -c -o /content/riscv_ise/genn/obj_dynamic/genn/genn/type.o type.cc
# type.cc: In instantiation of ‘GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)> [with auto:24 = long unsigned int; auto:25 = long int]’:
# /usr/include/c++/11/type_traits:2530:26:   required by substitution of ‘template<class _Fn, class ... _Args> static std::__result_of_success<decltype (declval<_Fn>()((declval<_Args>)()...)), std::__invoke_other> std::__result_of_other_impl::_S_test(int) [with _Fn = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Args = {const long unsigned int&, const long int&}]’
# /usr/include/c++/11/type_traits:2541:55:   required from ‘struct std::__result_of_impl<false, false, GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>, const long unsigned int&, const long int&>’
# /usr/include/c++/11/type_traits:2546:12:   required from ‘struct std::__invoke_result<GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>, const long unsigned int&, const long int&>’
# /usr/include/c++/11/bits/invoke.h:90:5:   required by substitution of ‘template<class _Callable, class ... _Args> constexpr typename std::__invoke_result<_Functor, _ArgTypes>::type std::__invoke(_Callable&&, _Args&& ...) [with _Callable = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Args = {const long unsigned int&, const long int&}]’
# /usr/include/c++/11/variant:1016:24:   required from ‘static constexpr decltype(auto) std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::__visit_invoke(_Visitor&&, _Variants ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {1, 2}]’
# /usr/include/c++/11/variant:1032:28:   required from ‘static constexpr auto std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply() [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {1, 2}]’
# /usr/include/c++/11/variant:968:56:   required from ‘static constexpr void std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...), __dimensions ...>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply_single_alt(_Tp&, _Tp*) [with bool __do_cookie = false; long unsigned int __index = 2; _Tp = std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&)>; _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&; long unsigned int ...__dimensions = {3}; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {1}]’
# /usr/include/c++/11/variant:947:48:   required from ‘constexpr const _Array_type std::__detail::__variant::__gen_vtable<std::__detail::__variant::__deduce_visit_result<bool>, GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&>::_S_vtable’
# /usr/include/c++/11/variant:1724:45:   required from ‘constexpr decltype(auto) std::__do_visit(_Visitor&&, _Variants&& ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}]’
# /usr/include/c++/11/variant:1766:30:   required from ‘constexpr std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> std::visit(_Visitor&&, _Variants&& ...) [with _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> = bool]’
# type.cc:36:22:   required from here
# /usr/include/c++/11/variant:1055:67:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply()’
# /usr/include/c++/11/variant:932:19:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply_all_alts<0, 1, 2>(__vtable, (std::make_index_sequence<3>(), std::make_index_sequence<3>()))’
# /usr/include/c++/11/variant:947:48:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply_single_alt<false, 1, std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3> >(__vtable.std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>::_M_arr[1], 0)’
# /usr/include/c++/11/variant:968:56:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3>, std::integer_sequence<long unsigned int, 1> >::_S_apply()’
# /usr/include/c++/11/variant:932:19:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3>, std::integer_sequence<long unsigned int, 1> >::_S_apply_all_alts<0, 1, 2>(__vtable, (std::make_index_sequence<3>(), std::make_index_sequence<3>()))’
# type.cc:39:22: warning: comparison of integer expressions of different signedness: ‘long unsigned int’ and ‘long int’ [-Wsign-compare]
#    39 |             return a == b;
#       |                    ~~^~~~
# type.cc: In instantiation of ‘GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)> [with auto:24 = long int; auto:25 = long unsigned int]’:
# /usr/include/c++/11/type_traits:2530:26:   required by substitution of ‘template<class _Fn, class ... _Args> static std::__result_of_success<decltype (declval<_Fn>()((declval<_Args>)()...)), std::__invoke_other> std::__result_of_other_impl::_S_test(int) [with _Fn = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Args = {const long int&, const long unsigned int&}]’
# /usr/include/c++/11/type_traits:2541:55:   required from ‘struct std::__result_of_impl<false, false, GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>, const long int&, const long unsigned int&>’
# /usr/include/c++/11/type_traits:2546:12:   required from ‘struct std::__invoke_result<GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>, const long int&, const long unsigned int&>’
# /usr/include/c++/11/bits/invoke.h:90:5:   required by substitution of ‘template<class _Callable, class ... _Args> constexpr typename std::__invoke_result<_Functor, _ArgTypes>::type std::__invoke(_Callable&&, _Args&& ...) [with _Callable = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Args = {const long int&, const long unsigned int&}]’
# /usr/include/c++/11/variant:1016:24:   required from ‘static constexpr decltype(auto) std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::__visit_invoke(_Visitor&&, _Variants ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {2, 1}]’
# /usr/include/c++/11/variant:1032:28:   required from ‘static constexpr auto std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply() [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {2, 1}]’
# /usr/include/c++/11/variant:968:56:   required from ‘static constexpr void std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...), __dimensions ...>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply_single_alt(_Tp&, _Tp*) [with bool __do_cookie = false; long unsigned int __index = 1; _Tp = std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&)>; _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&; long unsigned int ...__dimensions = {3}; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {2}]’
# /usr/include/c++/11/variant:947:48:   required from ‘constexpr const _Array_type std::__detail::__variant::__gen_vtable<std::__detail::__variant::__deduce_visit_result<bool>, GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&>::_S_vtable’
# /usr/include/c++/11/variant:1724:45:   required from ‘constexpr decltype(auto) std::__do_visit(_Visitor&&, _Variants&& ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}]’
# /usr/include/c++/11/variant:1766:30:   required from ‘constexpr std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> std::visit(_Visitor&&, _Variants&& ...) [with _Visitor = GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> = bool]’
# type.cc:36:22:   required from here
# /usr/include/c++/11/variant:1055:67:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply()’
# /usr/include/c++/11/variant:932:19:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply_all_alts<0, 1, 2>(__vtable, (std::make_index_sequence<3>(), std::make_index_sequence<3>()))’
# /usr/include/c++/11/variant:947:48:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply_single_alt<false, 2, std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3> >(__vtable.std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>::_M_arr[2], 0)’
# /usr/include/c++/11/variant:968:56:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3>, std::integer_sequence<long unsigned int, 2> >::_S_apply()’
# /usr/include/c++/11/variant:932:19:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator==(const GeNN::Type::NumericValue&) const::<lambda(auto:24, auto:25)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3>, std::integer_sequence<long unsigned int, 2> >::_S_apply_all_alts<0, 1, 2>(__vtable, (std::make_index_sequence<3>(), std::make_index_sequence<3>()))’
# type.cc:39:22: warning: comparison of integer expressions of different signedness: ‘long int’ and ‘long unsigned int’ [-Wsign-compare]
# type.cc: In instantiation of ‘GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)> [with auto:26 = long unsigned int; auto:27 = long int]’:
# /usr/include/c++/11/type_traits:2530:26:   required by substitution of ‘template<class _Fn, class ... _Args> static std::__result_of_success<decltype (declval<_Fn>()((declval<_Args>)()...)), std::__invoke_other> std::__result_of_other_impl::_S_test(int) [with _Fn = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Args = {const long unsigned int&, const long int&}]’
# /usr/include/c++/11/type_traits:2541:55:   required from ‘struct std::__result_of_impl<false, false, GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>, const long unsigned int&, const long int&>’
# /usr/include/c++/11/type_traits:2546:12:   required from ‘struct std::__invoke_result<GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>, const long unsigned int&, const long int&>’
# /usr/include/c++/11/bits/invoke.h:90:5:   required by substitution of ‘template<class _Callable, class ... _Args> constexpr typename std::__invoke_result<_Functor, _ArgTypes>::type std::__invoke(_Callable&&, _Args&& ...) [with _Callable = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Args = {const long unsigned int&, const long int&}]’
# /usr/include/c++/11/variant:1016:24:   required from ‘static constexpr decltype(auto) std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::__visit_invoke(_Visitor&&, _Variants ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {1, 2}]’
# /usr/include/c++/11/variant:1032:28:   required from ‘static constexpr auto std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply() [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {1, 2}]’
# /usr/include/c++/11/variant:968:56:   required from ‘static constexpr void std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...), __dimensions ...>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply_single_alt(_Tp&, _Tp*) [with bool __do_cookie = false; long unsigned int __index = 2; _Tp = std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&)>; _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&; long unsigned int ...__dimensions = {3}; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {1}]’
# /usr/include/c++/11/variant:947:48:   required from ‘constexpr const _Array_type std::__detail::__variant::__gen_vtable<std::__detail::__variant::__deduce_visit_result<bool>, GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&>::_S_vtable’
# /usr/include/c++/11/variant:1724:45:   required from ‘constexpr decltype(auto) std::__do_visit(_Visitor&&, _Variants&& ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}]’
# /usr/include/c++/11/variant:1766:30:   required from ‘constexpr std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> std::visit(_Visitor&&, _Variants&& ...) [with _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> = bool]’
# type.cc:46:22:   required from here
# /usr/include/c++/11/variant:1055:67:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply()’
# /usr/include/c++/11/variant:932:19:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply_all_alts<0, 1, 2>(__vtable, (std::make_index_sequence<3>(), std::make_index_sequence<3>()))’
# /usr/include/c++/11/variant:947:48:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply_single_alt<false, 1, std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3> >(__vtable.std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>::_M_arr[1], 0)’
# /usr/include/c++/11/variant:968:56:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3>, std::integer_sequence<long unsigned int, 1> >::_S_apply()’
# /usr/include/c++/11/variant:932:19:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3>, std::integer_sequence<long unsigned int, 1> >::_S_apply_all_alts<0, 1, 2>(__vtable, (std::make_index_sequence<3>(), std::make_index_sequence<3>()))’
# type.cc:49:22: warning: comparison of integer expressions of different signedness: ‘long unsigned int’ and ‘long int’ [-Wsign-compare]
#    49 |             return a != b;
#       |                    ~~^~~~
# type.cc: In instantiation of ‘GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)> [with auto:26 = long int; auto:27 = long unsigned int]’:
# /usr/include/c++/11/type_traits:2530:26:   required by substitution of ‘template<class _Fn, class ... _Args> static std::__result_of_success<decltype (declval<_Fn>()((declval<_Args>)()...)), std::__invoke_other> std::__result_of_other_impl::_S_test(int) [with _Fn = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Args = {const long int&, const long unsigned int&}]’
# /usr/include/c++/11/type_traits:2541:55:   required from ‘struct std::__result_of_impl<false, false, GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>, const long int&, const long unsigned int&>’
# /usr/include/c++/11/type_traits:2546:12:   required from ‘struct std::__invoke_result<GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>, const long int&, const long unsigned int&>’
# /usr/include/c++/11/bits/invoke.h:90:5:   required by substitution of ‘template<class _Callable, class ... _Args> constexpr typename std::__invoke_result<_Functor, _ArgTypes>::type std::__invoke(_Callable&&, _Args&& ...) [with _Callable = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Args = {const long int&, const long unsigned int&}]’
# /usr/include/c++/11/variant:1016:24:   required from ‘static constexpr decltype(auto) std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::__visit_invoke(_Visitor&&, _Variants ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {2, 1}]’
# /usr/include/c++/11/variant:1032:28:   required from ‘static constexpr auto std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...)>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply() [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {2, 1}]’
# /usr/include/c++/11/variant:968:56:   required from ‘static constexpr void std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<_Result_type (*)(_Visitor, _Variants ...), __dimensions ...>, std::integer_sequence<long unsigned int, __indices ...> >::_S_apply_single_alt(_Tp&, _Tp*) [with bool __do_cookie = false; long unsigned int __index = 1; _Tp = std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&)>; _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&; long unsigned int ...__dimensions = {3}; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; long unsigned int ...__indices = {2}]’
# /usr/include/c++/11/variant:947:48:   required from ‘constexpr const _Array_type std::__detail::__variant::__gen_vtable<std::__detail::__variant::__deduce_visit_result<bool>, GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&>::_S_vtable’
# /usr/include/c++/11/variant:1724:45:   required from ‘constexpr decltype(auto) std::__do_visit(_Visitor&&, _Variants&& ...) [with _Result_type = std::__detail::__variant::__deduce_visit_result<bool>; _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}]’
# /usr/include/c++/11/variant:1766:30:   required from ‘constexpr std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> std::visit(_Visitor&&, _Variants&& ...) [with _Visitor = GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>; _Variants = {const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&}; std::__detail::__variant::__visit_result_t<_Visitor, _Variants ...> = bool]’
# type.cc:46:22:   required from here
# /usr/include/c++/11/variant:1055:67:   in ‘constexpr’ expansion of ‘std::__detail::__variant::__gen_vtable_impl<std::__detail::__variant::_Multi_array<std::__detail::__variant::__deduce_visit_result<bool> (*)(GeNN::Type::NumericValue::operator!=(const GeNN::Type::NumericValue&) const::<lambda(auto:26, auto:27)>&&, const std::variant<double, long unsigned int, long int>&, const std::variant<double, long unsigned int, long int>&), 3, 3>, std::integer_sequence<long unsigned int> >::_S_apply()’
# ...
# mkdir -p /content/riscv_ise/pyfenn
# g++ -shared -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -fPIC -DGENN_VERSION=\"5.1.0\" -DGIT_HASH=\"50bb2fce54ba168b40675feb6c53dc8a1b8f9b23\" -o /content/riscv_ise/pyfenn/libgenn_dynamic.so /content/riscv_ise/genn/obj_dynamic/genn/genn/binomial.o /content/riscv_ise/genn/obj_dynamic/genn/genn/currentSource.o /content/riscv_ise/genn/obj_dynamic/genn/genn/currentSourceModels.o /content/riscv_ise/genn/obj_dynamic/genn/genn/customConnectivityUpdate.o /content/riscv_ise/genn/obj_dynamic/genn/genn/customConnectivityUpdateModels.o /content/riscv_ise/genn/obj_dynamic/genn/genn/customUpdate.o /content/riscv_ise/genn/obj_dynamic/genn/genn/customUpdateModels.o /content/riscv_ise/genn/obj_dynamic/genn/genn/gennUtils.o /content/riscv_ise/genn/obj_dynamic/genn/genn/initSparseConnectivitySnippet.o /content/riscv_ise/genn/obj_dynamic/genn/genn/initToeplitzConnectivitySnippet.o /content/riscv_ise/genn/obj_dynamic/genn/genn/initVarSnippet.o /content/riscv_ise/genn/obj_dynamic/genn/genn/logging.o /content/riscv_ise/genn/obj_dynamic/genn/genn/models.o /content/riscv_ise/genn/obj_dynamic/genn/genn/modelSpec.o /content/riscv_ise/genn/obj_dynamic/genn/genn/neuronGroup.o /content/riscv_ise/genn/obj_dynamic/genn/genn/neuronModels.o /content/riscv_ise/genn/obj_dynamic/genn/genn/postsynapticModels.o /content/riscv_ise/genn/obj_dynamic/genn/genn/snippet.o /content/riscv_ise/genn/obj_dynamic/genn/genn/synapseGroup.o /content/riscv_ise/genn/obj_dynamic/genn/genn/type.o /content/riscv_ise/genn/obj_dynamic/genn/genn/weightUpdateModels.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/backendBase.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/backendCUDAHIP.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/backendSIMT.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/codeGenUtils.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/codeStream.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/customConnectivityUpdateGroupMerged.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/customUpdateGroupMerged.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/environment.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/generateMakefile.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/generateModules.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/generateMSBuild.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/generateRunner.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/initGroupMerged.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/lazyString.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/modelSpecMerged.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/neuronUpdateGroupMerged.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/presynapticUpdateStrategySIMT.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/standardLibrary.o /content/riscv_ise/genn/obj_dynamic/genn/genn/code_generator/synapseUpdateGroupMerged.o /content/riscv_ise/genn/obj_dynamic/genn/genn/transpiler/errorHandler.o /content/riscv_ise/genn/obj_dynamic/genn/genn/transpiler/parser.o /content/riscv_ise/genn/obj_dynamic/genn/genn/transpiler/prettyPrinter.o /content/riscv_ise/genn/obj_dynamic/genn/genn/transpiler/scanner.o /content/riscv_ise/genn/obj_dynamic/genn/genn/transpiler/typeChecker.o /content/riscv_ise/genn/obj_dynamic/genn/genn/runtime/runtime.o
# make[1]: Leaving directory '/content/riscv_ise/genn/src/genn/genn'
# make -C src/ise
# make[1]: Entering directory '/content/riscv_ise/src/ise'
# mkdir -p /content/riscv_ise/obj_dynamic/ise/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/ise//dma_controller_sim.o dma_controller_sim.cc
# mkdir -p /content/riscv_ise/obj_dynamic/ise/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/ise//riscv.o riscv.cc
# mkdir -p /content/riscv_ise/obj_dynamic/ise/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -c -o /content/riscv_ise/obj_dynamic/ise//vector_processor.o vector_processor.cc
# vector_processor.cc: In member function ‘virtual void VectorProcessor::executeInstruction(uint32_t, uint32_t (&)[32], ScalarDataMemory&, uint32_t)’:
# vector_processor.cc:180:70: warning: unused parameter ‘pc’ [-Wunused-parameter]
#   180 |                                          ScalarDataMemory&, uint32_t pc)
#       |                                                             ~~~~~~~~~^~
# mkdir -p /content/riscv_ise/pyfenn
# g++ -shared -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -o /content/riscv_ise/pyfenn/libise_dynamic.so /content/riscv_ise/obj_dynamic/ise//dma_controller_sim.o /content/riscv_ise/obj_dynamic/ise//riscv.o /content/riscv_ise/obj_dynamic/ise//vector_processor.o
# make[1]: Leaving directory '/content/riscv_ise/src/ise'
# make -C src/backend
# make[1]: Entering directory '/content/riscv_ise/src/backend'
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//backend_fenn.o backend_fenn.cc
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//backend_fenn_hw.o backend_fenn_hw.cc
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//backend_fenn_sim.o backend_fenn_sim.cc
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//environment.o environment.cc
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//memory_allocator.o memory_allocator.cc
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//model.o model.cc
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//runtime.o runtime.cc
# mkdir -p /content/riscv_ise/obj_dynamic/backend/
# g++ -std=c++17 -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -c -o /content/riscv_ise/obj_dynamic/backend//special_functions.o special_functions.cc
# mkdir -p /content/riscv_ise/pyfenn
# g++ -shared -std=c++17 -march=native -Wall -Wpedantic -Wextra -MMD -MP -I/content/riscv_ise/include -fPIC -O3 -I/content/riscv_ise/genn/include/genn/genn -I/content/riscv_ise/genn/include/genn/third_party  -o /content/riscv_ise/pyfenn/libbackend_dynamic.so /content/riscv_ise/obj_dynamic/backend//backend_fenn.o /content/riscv_ise/obj_dynamic/backend//backend_fenn_hw.o /content/riscv_ise/obj_dynamic/backend//backend_fenn_sim.o /content/riscv_ise/obj_dynamic/backend//environment.o /content/riscv_ise/obj_dynamic/backend//memory_allocator.o /content/riscv_ise/obj_dynamic/backend//model.o /content/riscv_ise/obj_dynamic/backend//runtime.o /content/riscv_ise/obj_dynamic/backend//special_functions.o
# make[1]: Leaving directory '/content/riscv_ise/src/backend'
# running bdist_wheel
# running build
# running build_py
# creating build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/nir_import.py -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/__init__.py -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/utils.py -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/models.py -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/libgenn_dynamic.so -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/libbackend_dynamic.so -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/libise_dynamic.so -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/libcompiler_dynamic.so -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/libdisassembler_dynamic.so -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/libassembler_dynamic.so -> build/lib.linux-x86_64-cpython-312/pyfenn
# copying pyfenn/libcommon_dynamic.so -> build/lib.linux-x86_64-cpython-312/pyfenn
# running build_ext
# building '_fenn' extension
# creating build/temp.linux-x86_64-cpython-312/content/riscv_ise/pyfenn/src
# x86_64-linux-gnu-g++ -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -DLINKING_ASSEMBLER_DLL=1 -DLINKING_BACKEND_DLL=1 -DLINKING_COMMON_DLL=1 -DLINKING_COMPILER_DLL=1 -DLINKING_ISE_DLL=1 -DLINKING_COMPILER_DLL=1 -DLINKING_GENN_DLL=1 -DLINKING_DISASSEMBLER_DLL=1 -I/content/riscv_ise/include -I/content/riscv_ise/genn/include/genn/third_party -I/content/riscv_ise/genn/include/genn/genn -I/usr/local/lib/python3.12/dist-packages/pybind11/include -I/usr/include/python3.12 -c /content/riscv_ise/pyfenn/src/fenn.cc -o build/temp.linux-x86_64-cpython-312/content/riscv_ise/pyfenn/src/fenn.o -fvisibility=hidden -g0 -std=c++17
# x86_64-linux-gnu-g++ -fno-strict-overflow -Wsign-compare -DNDEBUG -g -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-312/content/riscv_ise/pyfenn/src/fenn.o -L/content/riscv_ise/pyfenn -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-rpath,$ORIGIN -lgenn_dynamic -lbackend_dynamic -lise_dynamic -lcompiler_dynamic -ldisassembler_dynamic -lassembler_dynamic -lcommon_dynamic -lffi -o build/lib.linux-x86_64-cpython-312/pyfenn/_fenn.cpython-312-x86_64-linux-gnu.so
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/nir_import.py -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/__init__.py -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/libbackend_dynamic.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/utils.py -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/libcompiler_dynamic.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/libassembler_dynamic.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/libgenn_dynamic.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/models.py -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/_fenn.cpython-312-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/libdisassembler_dynamic.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/libise_dynamic.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# copying build/lib.linux-x86_64-cpython-312/pyfenn/libcommon_dynamic.so -> build/bdist.linux-x86_64/wheel/./pyfenn
# running install_egg_info
# running egg_info
# creating pyfenn.egg-info
# writing pyfenn.egg-info/PKG-INFO
# writing dependency_links to pyfenn.egg-info/dependency_links.txt
# writing requirements to pyfenn.egg-info/requires.txt
# writing top-level names to pyfenn.egg-info/top_level.txt
# writing manifest file 'pyfenn.egg-info/SOURCES.txt'
# dependency /content/riscv_ise/pyfenn/libgenn_dynamic.so won't be automatically included in the manifest: the path must be relative
# dependency /content/riscv_ise/pyfenn/docStrings.h won't be automatically included in the manifest: the path must be relative
# dependency /content/riscv_ise/pyfenn/libbackend_dynamic.so won't be automatically included in the manifest: the path must be relative
# dependency /content/riscv_ise/pyfenn/libise_dynamic.so won't be automatically included in the manifest: the path must be relative
# dependency /content/riscv_ise/pyfenn/libcompiler_dynamic.so won't be automatically included in the manifest: the path must be relative
# dependency /content/riscv_ise/pyfenn/libdisassembler_dynamic.so won't be automatically included in the manifest: the path must be relative
# dependency /content/riscv_ise/pyfenn/libassembler_dynamic.so won't be automatically included in the manifest: the path must be relative
# dependency /content/riscv_ise/pyfenn/libcommon_dynamic.so won't be automatically included in the manifest: the path must be relative
# reading manifest file 'pyfenn.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'pyfenn.egg-info/SOURCES.txt'
# Copying pyfenn.egg-info to build/bdist.linux-x86_64/wheel/./pyfenn-0.0.1-py3.12.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/pyfenn-0.0.1.dist-info/WHEEL
# creating 'dist/pyfenn-0.0.1-cp312-cp312-linux_x86_64.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'pyfenn/__init__.py'
# adding 'pyfenn/_fenn.cpython-312-x86_64-linux-gnu.so'
# adding 'pyfenn/libassembler_dynamic.so'
# adding 'pyfenn/libbackend_dynamic.so'
# adding 'pyfenn/libcommon_dynamic.so'
# adding 'pyfenn/libcompiler_dynamic.so'
# adding 'pyfenn/libdisassembler_dynamic.so'
# adding 'pyfenn/libgenn_dynamic.so'
# adding 'pyfenn/libise_dynamic.so'
# adding 'pyfenn/models.py'
# adding 'pyfenn/nir_import.py'
# adding 'pyfenn/utils.py'
# adding 'pyfenn-0.0.1.dist-info/LICENSE'
# adding 'pyfenn-0.0.1.dist-info/METADATA'
# adding 'pyfenn-0.0.1.dist-info/WHEEL'
# adding 'pyfenn-0.0.1.dist-info/top_level.txt'
# adding 'pyfenn-0.0.1.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel

# %% [markdown]
# # Save wheel to Google Drive
# First mount Google drive

# %%
2from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# and then copy wheel file into folder with tutorials

# %%
from platform import python_implementation, python_version_tuple
from shutil import copy
#from wheel.bdist_wheel import get_abi_tag, get_platform

assert python_implementation() == "CPython"
version_tuple = python_version_tuple()
#wheel_name = f"pyfenn-0.0.1-cp{version_tuple[0]}{version_tuple[1]}-{get_abi_tag()}-{get_platform(None)}.whl"
wheel_name = f"pyfenn-0.0.1-cp{version_tuple[0]}{version_tuple[1]}-cp312-linux_x86_64.whl"
copy(f"/content/riscv_ise/dist/{wheel_name}", f"/content/drive/MyDrive/genn_tutorials/{wheel_name}")
# Out:
# '/content/drive/MyDrive/genn_tutorials/pyfenn-0.0.1-cp312-cp312-linux_x86_64.whl'
